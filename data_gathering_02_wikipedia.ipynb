# %% [markdown]
# В приложении парсинга википедии получить первую ссылку из раздела "Ссылки"
#
# и вывести все значимые слова из неё. Результат записать в файл в форматированном виде.

# %%
from pprint import pprint
import requests
import re

# %%
def get_topic():
    topic = input('О чем исследуем статью в Вики? ')
    return topic

def get_link():
    link='https://ru.wikipedia.org/wiki/'+get_topic().capitalize()
    return link

def get_topic_page():
    answer = ''
    article_text = ''
    while answer != 'N':
        link = get_link()
        response = requests.get(link)
        article_text = response.text
        if str(response) == '<Response [200]>':
            return article_text
        else:
            answer = input('Такой статьи, кажется, пока нет. Продолжим? Y/N')
            if answer != 'N':
                continue
            elif answer == 'N':
                print('До встречи!')
                break

# %%
html = get_topic_page()
# Out:
# О чем исследуем статью в Вики? Дерево

# %%
print(len(html))
# Out:
# 207119

# %%
def get_reference(html_content):
    words = re.findall(r'id="Ссылки">[\s\S]*<ul><li><a rel="nofollow" class="external text" href="(.+)"', html_content)

    return words

# %%
reference_link = str(get_reference(html)[0])

# %%
print(reference_link)
# Out:
# http://transspot.ru/2013/05/31/pro-derevya-na-ulicax/

# %%
reference_text = requests.get(reference_link).text

# %%
def get_words(html_content):
    words = re.findall("[а-яА-Я]{3,}",html_content)
    return words

def get_common_words(topic):
    words_list = get_words(topic)
    rate={}
    for word in words_list:
        if word in rate:
            rate[word]+=1
        else:
            rate[word]=1
    rate_list = list(rate.items())
    rate_list.sort(key = lambda x: -x[1])
    return rate_list

# %%
dict1 = get_common_words(reference_text)
pprint(dict1)
# Out:
# [('движения', 26),
#  ('деревьев', 25),
#  ('для', 23),
#  ('деревья', 19),
#  ('городе', 17),
#  ('Деревья', 16),
#  ('дорожного', 13),
#  ('улицах', 11),
#  ('ТрансСпот', 11),
#  ('Про', 9),
#  ('дороги', 9),
#  ('воздуха', 8),
#  ('БДД', 8),
#  ('дерево', 8),
#  ('дерева', 7),
#  ('безопасность', 7),
#  ('Организация', 7),
#  ('это', 7),
#  ('Скорость', 6),
#  ('Дороги', 6),
#  ('Давыдов', 6),
#  ('Транспорт', 6),
#  ('Литература', 6),
#  ('что', 6),
#  ('среда', 6),
#  ('водителей', 6),
#  ('деревьями', 6),
#  ('шума', 6),
#  ('контроль', 5),
#  ('ДТП', 5),
#  ('ОДД', 5),
#  ('Экология', 5),
#  ('Лента', 5),
#  ('Новости', 5),
#  ('Транспортные', 5),
#  ('транспорта', 5),
#  ('окружающая', 5),
#  ('движение', 5),
#  ('высадки', 5),
#  ('улицы', 5),
#  ('при', 5),
#  ('пешеходов', 5),
#  ('будет', 5),
#  ('жизни', 5),
#  ('животных', 5),
#  ('Патрик', 5),
#  ('комментарий', 5),
#  ('городских', 4),
#  ('организации', 4),
#  ('пыльцу', 4),
#  ('Сергей', 4),
#  ('Главная', 4),
#  ('развязки', 4),
#  ('Лондон', 4),
#  ('нарушения', 4),
#  ('Москва', 4),
#  ('Влияние', 4),
#  ('дорожное', 4),
#  ('жизнь', 4),
#  ('Основания', 4),
#  ('Отрицательные', 4),
#  ('стороны', 4),
#  ('присутствия', 4),
#  ('Идеальное', 4),
#  ('городской', 4),
#  ('Вертикальные', 4),
#  ('сады', 4),
#  ('Патрика', 4),
#  ('Блана', 4),
#  ('того', 4),
#  ('Это', 4),
#  ('водителя', 4),
#  ('или', 4),
#  ('например', 4),
#  ('как', 4),
#  ('могут', 4),
#  ('проезжей', 4),
#  ('корни', 4),
#  ('новых', 4),
#  ('Бланк', 4),
#  ('Роль', 3),
#  ('Очищение', 3),
#  ('климат', 3),
#  ('средство', 3),
#  ('углекислый', 3),
#  ('газ', 3),
#  ('климата', 3),
#  ('аллергия', 3),
#  ('сайте', 3),
#  ('Связаться', 3),
#  ('Статьи', 3),
#  ('Содержание', 3),
#  ('Градостроительство', 3),
#  ('комментарии', 3),
#  ('Все', 3),
#  ('Социальная', 3),
#  ('реклама', 3),
#  ('Инфографика', 3),
#  ('оценка', 3),
#  ('пешеходных', 3),
#  ('ограждений', 3),
#  ('Пешеходное', 3),
#  ('ограждение', 3),
#  ('типовые', 3),
#  ('пешеходами', 3),
#  ('похорошела', 3),
#  ('имеют', 3),
#  ('всего', 3),
#  ('углекислого', 3),
#  ('газа', 3),
#  ('города', 3),
#  ('Кроме', 3),
#  ('поверхности', 3),
#  ('мелкие', 3),
#  ('либо', 3),
#  ('листьев', 3),
#  ('кислород', 3),
#  ('являются', 3),
#  ('тени', 3),
#  ('более', 3),
#  ('тень', 3),
#  ('около', 3),
#  ('При', 3),
#  ('под', 3),
#  ('Однако', 3),
#  ('также', 3),
#  ('водитель', 3),
#  ('влияние', 3),
#  ('если', 3),
#  ('направления', 3),
#  ('нет', 3),
#  ('улице', 3),
#  ('части', 3),
#  ('место', 3),
#  ('людей', 3),
#  ('дуба', 3),
#  ('может', 3),
#  ('вопрос', 3),
#  ('улиц', 3),
#  ('быть', 3),
#  ('защищает', 3),
#  ('кроны', 3),
#  ('ствол', 3),
#  ('ответах', 3),
#  ('Еженедельная', 3),
#  ('рассылка', 3),
#  ('растительность', 2),
#  ('улица', 2),
#  ('экология', 2),
#  ('ветер', 2),
#  ('транспорт', 2),
#  ('комментариев', 2),
#  ('Услуги', 2),
#  ('Помочь', 2),
#  ('проекту', 2),
#  ('Предложить', 2),
#  ('новость', 2),
#  ('Архив', 2),
#  ('записей', 2),
#  ('Движение', 2),
#  ('Заметки', 2),
#  ('новости', 2),
#  ('СМИ', 2),
#  ('Заграница', 2),
#  ('Медиа', 2),
#  ('калькуляторы', 2),
#  ('Картинки', 2),
#  ('Видео', 2),
#  ('Карты', 2),
#  ('Интерактив', 2),
#  ('Библиотека', 2),
#  ('Нормативная', 2),
#  ('документация', 2),
#  ('Термины', 2),
#  ('определения', 2),
#  ('Блоги', 2),
#  ('Интересные', 2),
#  ('ссылки', 2),
#  ('Чердак', 2),
#  ('Вне', 2),
#  ('перед', 2),
#  ('нашли', 2),
#  ('Ключевые', 2),
#  ('слова', 2),
#  ('Итого', 2),
#  ('вредных', 2),
#  ('веществ', 2),
#  ('листья', 2),
#  ('частицы', 2),
#  ('растений', 2),
#  ('зависит', 2),
#  ('Преобразование', 2),
#  ('увлажнения', 2),
#  ('воды', 2),
#  ('городов', 2),
#  ('температуру', 2),
#  ('этом', 2),
#  ('Еще', 2),
#  ('больше', 2),
#  ('учитывать', 2),
#  ('группы', 2),
#  ('значения', 2),
#  ('уровень', 2),
#  ('транспортный', 2),
#  ('меньше', 2),
#  ('ветра', 2),
#  ('транспортных', 2),
#  ('есть', 2),
#  ('негативное', 2),
#  ('Уличные', 2),
#  ('зимой', 2),
#  ('несколько', 2),
#  ('функция', 2),
#  ('рекомендациях', 2),
#  ('безопасности', 2),
#  ('автомобильных', 2),
#  ('которых', 2),
#  ('должны', 2),
#  ('Использование', 2),
#  ('подчеркивания', 2),
#  ('так', 2),
#  ('скорость', 2),
#  ('следствие', 2),
#  ('велосипедистов', 2),
#  ('Отгораживание', 2),
#  ('без', 2),
#  ('особенности', 2),
#  ('можно', 2),
#  ('вещества', 2),
#  ('Уменьшают', 2),
#  ('Улучшают', 2),
#  ('дорог', 2),
#  ('время', 2),
#  ('аллергии', 2),
#  ('пыльцы', 2),
#  ('количество', 2),
#  ('воздействии', 2),
#  ('окружающей', 2),
#  ('среды', 2),
#  ('свои', 2),
#  ('функции', 2),
#  ('только', 2),
#  ('хорошо', 2),
#  ('необходимо', 2),
#  ('пространства', 2),
#  ('виды', 2),
#  ('тепла', 2),
#  ('тяжелого', 2),
#  ('Без', 2),
#  ('растениями', 2),
#  ('Глубокие', 2),
#  ('повреждений', 2),
#  ('сухих', 2),
#  ('веток', 2),
#  ('сайта', 2),
#  ('Петербург', 2),
#  ('Отправить', 2),
#  ('Имя', 2),
#  ('Введите', 2),
#  ('символы', 2),
#  ('Вставьте', 2),
#  ('код', 2),
#  ('Сообщать', 2),
#  ('этот', 2),
#  ('Оставить', 2),
#  ('Сообщить', 2),
#  ('пересечения', 2),
#  ('Программы', 2),
#  ('Новгород', 2),
#  ('Сообщением', 2),
#  ('обработку', 2),
#  ('персональных', 2),
#  ('данных', 2),
#  ('Текст', 2),
#  ('Адрес', 2),
#  ('электронной', 2),
#  ('почты', 2),
#  ('Трансспот', 1),
#  ('одной', 1),
#  ('строкой', 1),
#  ('Четыре', 1),
#  ('светофора', 1),
#  ('Источник', 1),
#  ('Нарядные', 1),
#  ('рождеством', 1),
#  ('искали', 1),
#  ('Тогда', 1),
#  ('мощные', 1),
#  ('технологии', 1),
#  ('поиска', 1),
#  ('сайту', 1),
#  ('Вам', 1),
#  ('помогут', 1),
#  ('Бонус', 1),
#  ('огромное', 1),
#  ('значение', 1),
#  ('защите', 1),
#  ('городского', 1),
#  ('Прежде', 1),
#  ('снижение', 1),
#  ('концентрации', 1),
#  ('автомобиля', 1),
#  ('Часть', 1),
#  ('озона', 1),
#  ('оксидов', 1),
#  ('азота', 1),
#  ('окиси', 1),
#  ('углерода', 1),
#  ('диоксида', 1),
#  ('серы', 1),
#  ('Именно', 1),
#  ('поэтому', 1),
#  ('парки', 1),
#  ('называют', 1),
#  ('легкими', 1),
#  ('собирают', 1),
#  ('своей', 1),
#  ('после', 1),
#  ('чего', 1),
#  ('эти', 1),
#  ('остаются', 1),
#  ('листьях', 1),
#  ('виноград', 1),
#  ('смываются', 1),
#  ('дождевой', 1),
#  ('водой', 1),
#  ('платан', 1),
#  ('свойств', 1),
#  ('очищения', 1),
#  ('своего', 1),
#  ('рода', 1),
#  ('кондиционером', 1),
#  ('Функция', 1),
#  ('отбрасывания', 1),
#  ('повышенной', 1),
#  ('температуре', 1),
#  ('транспирация', 1),
#  ('испарение', 1),
#  ('растением', 1),
#  ('становятся', 1),
#  ('важными', 1),
#  ('ростом', 1),
#  ('Таким', 1),
#  ('образом', 1),
#  ('охлаждая', 1),
#  ('отбрасывая', 1),
#  ('сглаживают', 1),
#  ('экстремальную', 1),
#  ('положительную', 1),
#  ('Разность', 1),
#  ('температур', 1),
#  ('парках', 1),
#  ('площадях', 1),
#  ('составляет', 1),
#  ('ощущаемая', 1),
#  ('разность', 1),
#  ('достигает', 1),
#  ('отличается', 1),
#  ('температура', 1),
#  ('над', 1),
#  ('асфальтом', 1),
#  ('солнце', 1),
#  ('Здесь', 1),
#  ('важно', 1),
#  ('эффект', 1),
#  ('намного', 1),
#  ('выражен', 1),
#  ('нежели', 1),
#  ('одиноко', 1),
#  ('стоящего', 1),
#  ('Также', 1),
#  ('следует', 1),
#  ('упомянуть', 1),
#  ('роли', 1),
#  ('шумоизолятора', 1),
#  ('Измеренные', 1),
#  ('снижения', 1),
#  ('уровня', 1),
#  ('показывают', 1),
#  ('редкие', 1),
#  ('уличные', 1),
#  ('лишь', 1),
#  ('незначительно', 1),
#  ('снижают', 1),
#  ('нельзя', 1),
#  ('недооценивать', 1),
#  ('психологическое', 1),
#  ('воздействие', 1),
#  ('скрываемый', 1),
#  ('поток', 1),
#  ('ощущениям', 1),
#  ('производит', 1),
#  ('гораздо', 1),
#  ('Визуальная', 1),
#  ('защита', 1),
#  ('возраста', 1),
#  ('количества', 1),
#  ('Особенно', 1),
#  ('эффективными', 1),
#  ('обширным', 1),
#  ('ветвлением', 1),
#  ('большим', 1),
#  ('количеством', 1),
#  ('мелких', 1),
#  ('защищают', 1),
#  ('местах', 1),
#  ('частыми', 1),
#  ('ветрами', 1),
#  ('практикуют', 1),
#  ('высаживание', 1),
#  ('аллей', 1),
#  ('Приходиться', 1),
#  ('слышать', 1),
#  ('дорожно', 1),
#  ('происшествиях', 1),
#  ('связанных', 1),
#  ('машина', 1),
#  ('врезается', 1),
#  ('получает', 1),
#  ('травмы', 1),
#  ('представить', 1),
#  ('месте', 1),
#  ('пешехода', 1),
#  ('тротуаре', 1),
#  ('виноватым', 1),
#  ('становиться', 1),
#  ('пешеход', 1),
#  ('Чаще', 1),
#  ('столкновения', 1),
#  ('происходят', 1),
#  ('причине', 1),
#  ('правил', 1),
#  ('нетрезвого', 1),
#  ('состояния', 1),
#  ('выполняют', 1),
#  ('важных', 1),
#  ('функций', 1),
#  ('Первая', 1),
#  ('предупреждение', 1),
#  ('изменении', 1),
#  ('указание', 1),
#  ('наличие', 1),
#  ('перекрестка', 1),
#  ('Эта', 1),
#  ('описана', 1),
#  ('отечественных', 1),
#  ('обеспечению', 1),
#  ('дорогах', 1),
#  ('учетом', 1),
#  ('проектироваться', 1),
#  ('Чего', 1),
#  ('этих', 1),
#  ('позволяют', 1),
#  ('контролировать', 1),
#  ('поведение', 1),
#  ('дороге', 1),
#  ('Чем', 1),
#  ('стесненней', 1),
#  ('условия', 1),
#  ('тем', 1),
#  ('низкая', 1),
#  ('комфортная', 1),
#  ('выше', 1),
#  ('напряжение', 1),
#  ('внимательность', 1),
#  ('свою', 1),
#  ('очередь', 1),
#  ('увеличивает', 1),
#  ('Чуть', 1),
#  ('позже', 1),
#  ('подробная', 1),
#  ('статья', 1),
#  ('про', 1),
#  ('оптическое', 1),
#  ('восприятие', 1),
#  ('Дополнительно', 1),
#  ('служить', 1),
#  ('естественной', 1),
#  ('преградой', 1),
#  ('между', 1),
#  ('частью', 1),
#  ('тротуаром', 1),
#  ('позволяя', 1),
#  ('пешеходам', 1),
#  ('комфортно', 1),
#  ('чувствовать', 1),
#  ('себя', 1),
#  ('Практически', 1),
#  ('любому', 1),
#  ('человеку', 1),
#  ('приятно', 1),
#  ('видеть', 1),
#  ('зелень', 1),
#  ('домом', 1),
#  ('прогулке', 1),
#  ('Даже', 1),
#  ('отличная', 1),
#  ('экологическая', 1),
#  ('обстановка', 1),
#  ('белок', 1),
#  ('журавлей', 1),
#  ('животные', 1),
#  ('обитающие', 1),
#  ('деревьях', 1),
#  ('опять', 1),
#  ('приносят', 1),
#  ('множество', 1),
#  ('положительных', 1),
#  ('эмоций', 1),
#  ('детям', 1),
#  ('Подводя', 1),
#  ('итог', 1),
#  ('перечислить', 1),
#  ('следующие', 1),
#  ('основания', 1),
#  ('фильтруют', 1),
#  ('вредные', 1),
#  ('находящиеся', 1),
#  ('воздухе', 1),
#  ('Отбрасывают', 1),
#  ('уменьшают', 1),
#  ('предметов', 1),
#  ('попадающих', 1),
#  ('Повышают', 1),
#  ('влажность', 1),
#  ('Потребляют', 1),
#  ('производят', 1),
#  ('Скрывают', 1),
#  ('источник', 1),
#  ('глаз', 1),
#  ('Снижают', 1),
#  ('нагрузку', 1),
#  ('ливневую', 1),
#  ('канализацию', 1),
#  ('впитывая', 1),
#  ('дождевую', 1),
#  ('воду', 1),
#  ('Увеличивают', 1),
#  ('участников', 1),
#  ('распознаваемость', 1),
#  ('элементов', 1),
#  ('Являются', 1),
#  ('местом', 1),
#  ('самочувствие', 1),
#  ('Стоит', 1),
#  ('отметить', 1),
#  ('прочих', 1),
#  ('настоящее', 1),
#  ('оценке', 1),
#  ('немецких', 1),
#  ('аллергологов', 1),
#  ('Германии', 1),
#  ('уже', 1),
#  ('страдает', 1),
#  ('миллионов', 1),
#  ('человек', 1),
#  ('основном', 1),
#  ('дети', 1),
#  ('подростки', 1),
#  ('прогнозам', 1),
#  ('году', 1),
#  ('беспокоить', 1),
#  ('жителей', 1),
#  ('Европы', 1),
#  ('Причин', 1),
#  ('увеличения', 1),
#  ('аллергиков', 1),
#  ('скорее', 1),
#  ('Одна', 1),
#  ('причин', 1),
#  ('изменение', 1),
#  ('которое', 1),
#  ('ведет', 1),
#  ('продлению', 1),
#  ('периода', 1),
#  ('цветения', 1),
#  ('выделения', 1),
#  ('Вторая', 1),
#  ('причина', 1),
#  ('враждебная', 1),
#  ('городская', 1),
#  ('воздействием', 1),
#  ('которой', 1),
#  ('стресса', 1),
#  ('выделяет', 1),
#  ('большее', 1),
#  ('аллергенные', 1),
#  ('содержащиеся', 1),
#  ('пыльце', 1),
#  ('совместном', 1),
#  ('вредными', 1),
#  ('веществами', 1),
#  ('высокую', 1),
#  ('агрессивность', 1),
#  ('Наибольшее', 1),
#  ('распространение', 1),
#  ('орешника', 1),
#  ('ольхи', 1),
#  ('березы', 1),
#  ('бука', 1),
#  ('тополя', 1),
#  ('Сезонность', 1),
#  ('работы', 1),
#  ('показаться', 1),
#  ('проблемой', 1),
#  ('Активно', 1),
#  ('выполнять', 1),
#  ('все', 1),
#  ('мая', 1),
#  ('сентябрь', 1),
#  ('внимательно', 1),
#  ('рассмотреть', 1),
#  ('увидеть', 1),
#  ('некоторые', 1),
#  ('важные', 1),
#  ('задачи', 1),
#  ('решения', 1),
#  ('подходит', 1),
#  ('возникает', 1),
#  ('летний', 1),
#  ('период', 1),
#  ('Отбрасывание', 1),
#  ('охлаждение', 1),
#  ('летом', 1),
#  ('Производство', 1),
#  ('озон', 1),
#  ('увеличивается', 1),
#  ('повышении', 1),
#  ('температуры', 1),
#  ('солнечных', 1),
#  ('лучей', 1),
#  ('всесезонные', 1),
#  ('такие', 1),
#  ('организация', 1),
#  ('обеспечение', 1),
#  ('места', 1),
#  ('улучшение', 1),
#  ('самочувствия', 1),
#  ('выборе', 1),
#  ('растительности', 1),
#  ('должно', 1),
#  ('доминирующих', 1),
#  ('видов', 1),
#  ('вызвать', 1),
#  ('аллергию', 1),
#  ('горожан', 1),
#  ('привести', 1),
#  ('резкому', 1),
#  ('вымиранию', 1),
#  ('вида', 1),
#  ('болезни', 1),
#  ('Ниже', 1),
#  ('перечислены', 1),
#  ('требования', 1),
#  ('уличным', 1),
#  ('деревьям', 1),
#  ('рекомендуемые', 1),
#  ('Лист', 1),
#  ('Блестящая', 1),
#  ('внешняя', 1),
#  ('поверхность', 1),
#  ('листа', 1),
#  ('китайской', 1),
#  ('груши', 1),
#  ('отражает', 1),
#  ('солнечные', 1),
#  ('лучи', 1),
#  ('излишнего', 1),
#  ('Мелкие', 1),
#  ('испаряют', 1),
#  ('влаги', 1),
#  ('Ширина', 1),
#  ('Узкая', 1),
#  ('форма', 1),
#  ('соответствует', 1),
#  ('узкому', 1),
#  ('пространству', 1),
#  ('Гледичия', 1),
#  ('столбчатая', 1),
#  ('Обеспечение', 1),
#  ('Ствол', 1),
#  ('разветвления', 1),
#  ('счет', 1),
#  ('высокой', 1),
#  ('позволяет', 1),
#  ('Такой', 1),
#  ('отсутствует', 1),
#  ('черешчатого', 1),
#  ('красного', 1),
#  ('наоборот', 1),
#  ('нужный', 1),
#  ('Когда', 1),
#  ('крона', 1),
#  ('дорастает', 1),
#  ('кроной', 1),
#  ('достаточно', 1),
#  ('проезда', 1),
#  ('грузовиков', 1),
#  ('отростков', 1),
#  ('строительных', 1),
#  ('мероприятий', 1),
#  ('повреждены', 1),
#  ('давать', 1),
#  ('побегов', 1),
#  ('Недопустимыми', 1),
#  ('этому', 1),
#  ('критерию', 1),
#  ('робинии', 1),
#  ('тополи', 1),
#  ('кавказская', 1),
#  ('лапина', 1),
#  ('часто', 1),
#  ('достигают', 1),
#  ('грунтовых', 1),
#  ('вод', 1),
#  ('Дерево', 1),
#  ('становится', 1),
#  ('менее', 1),
#  ('зависимым', 1),
#  ('Кора', 1),
#  ('крепкий', 1),
#  ('слой', 1),
#  ('коры', 1),
#  ('мочи', 1),
#  ('собак', 1),
#  ('физических', 1),
#  ('Пробковая', 1),
#  ('кора', 1),
#  ('лещину', 1),
#  ('древовидную', 1),
#  ('гинкго', 1),
#  ('Свойства', 1),
#  ('саженцев', 1),
#  ('Пересадка', 1),
#  ('питомника', 1),
#  ('обеспечивают', 1),
#  ('наивысшую', 1),
#  ('вероятность', 1),
#  ('удачного', 1),
#  ('выращивания', 1),
#  ('Древесина', 1),
#  ('длинных', 1),
#  ('волокон', 1),
#  ('эластична', 1),
#  ('предотвращает', 1),
#  ('повреждения', 1),
#  ('ветром', 1),
#  ('Сопротивление', 1),
#  ('болезням', 1),
#  ('Образование', 1),
#  ('Некоторые', 1),
#  ('образуют', 1),
#  ('большое', 1),
#  ('Старый', 1),
#  ('ясень', 1),
#  ('сбрасывать', 1),
#  ('мертвые', 1),
#  ('ветки', 1),
#  ('является', 1),
#  ('причиной', 1),
#  ('различных', 1),
#  ('опадания', 1),
#  ('фруктов', 1),
#  ('Большие', 1),
#  ('фрукты', 1),
#  ('увеличивают', 1),
#  ('затраты', 1),
#  ('содержание', 1),
#  ('кроме', 1),
#  ('причинами', 1),
#  ('аварий', 1),
#  ('Блан', 1),
#  ('биолог', 1),
#  ('дизайнер', 1),
#  ('Украшает', 1),
#  ('вертикальные', 1),
#  ('городах', 1),
#  ('Фотографии', 1),
#  ('Если', 1),
#  ('ошибку', 1),
#  ('пожалуйста', 1),
#  ('выделите', 1),
#  ('фрагмент', 1),
#  ('текста', 1),
#  ('нажмите', 1),
#  ('Записи', 1),
#  ('Владелец', 1),
#  ('Проектирую', 1),
#  ('автомобильные', 1),
#  ('Планирую', 1),
#  ('моделирую', 1),
#  ('транспортные', 1),
#  ('потоки', 1),
#  ('Участвую', 1),
#  ('научно', 1),
#  ('исследовательских', 1),
#  ('работах', 1),
#  ('концепции', 1),
#  ('развития', 1),
#  ('раздел', 1),
#  ('Читаю', 1),
#  ('лекции', 1),
#  ('проектированию', 1),
#  ('развязок', 1),
#  ('ЦНТИ', 1),
#  ('Прогресс', 1),
#  ('Эксперт', 1),
#  ('Красивый', 1),
#  ('Консультант', 1),
#  ('Института', 1),
#  ('дизайна', 1),
#  ('урбанистики', 1),
#  ('ИТМО', 1),
#  ('Интересуюсь', 1),
#  ('всем', 1),
#  ('транспортно', 1),
#  ('дорожным', 1),
#  ('безопасностью', 1),
#  ('ответ', 1),
#  ('Войти', 1),
#  ('помощью', 1),
#  ('аккаунта', 1),
#  ('социальной', 1),
#  ('сети', 1),
#  ('Начать', 1),
#  ('обсуждение', 1),
#  ('Присоединиться', 1),
#  ('обсуждению', 1),
#  ('комментариях', 1),
#  ('мой', 1),
#  ('пешеходный', 1),
#  ('Невский', 1),
#  ('проспект', 1),
#  ('Прага', 1),
#  ('Запрет', 1),
#  ('велосипедного', 1),
#  ('центре', 1),
#  ('предложения', 1),
#  ('автомобилистов', 1),
#  ('примере', 1),
#  ('Кирова', 1),
#  ('Астана', 1),
#  ('Переход', 1),
#  ('флажком', 1),
#  ('Петербурге', 1),
#  ('остро', 1),
#  ('хватает', 1),
#  ('подземных', 1),
#  ('переходов', 1),
#  ('Рекомендации', 1),
#  ('Минтранса', 1),
#  ('успокоению', 1),
#  ('Велосипедные', 1),
#  ('замечания', 1),
#  ('Стандарту', 1),
#  ('кольцевые', 1),
#  ('Твиты', 1),
#  ('почему', 1),
#  ('красных', 1),
#  ('трусов', 1),
#  ('поверх', 1),
#  ('лосин', 1),
#  ('другой', 1),
#  ('совсем', 1),
#  ('Как', 1),
#  ('невозможно', 1),
#  ('запрет', 1),
#  ('авто', 1),
#  ('стандартов', 1),
#  ('провилам', 1),
#  ('Каких', 1),
#  ('Где', 1),
#  ('конкретика', 1),
#  ('Даш', 1),
#  ('почитать', 1),
#  ('Выбор', 1),
#  ('темы', 1),
#  ('Основные', 1),
#  ('Города', 1),
#  ('страны', 1),
#  ('Люди', 1),
#  ('Организации', 1),
#  ('Автобан', 1),
#  ('Алкоголь', 1),
#  ('Биопереходы', 1),
#  ('Дорожная', 1),
#  ('диета', 1),
#  ('Есть', 1),
#  ('Загородные', 1),
#  ('Запретить', 1),
#  ('Инновации', 1),
#  ('Карта', 1),
#  ('Лекции', 1),
#  ('Ограничение', 1),
#  ('ПДД', 1),
#  ('Платная', 1),
#  ('парковка', 1),
#  ('Платные', 1),
#  ('Пропускная', 1),
#  ('способность', 1),
#  ('Работа', 1),
#  ('Расчет', 1),
#  ('Светофор', 1),
#  ('Соцопрос', 1),
#  ('Статистика', 1),
#  ('Темы', 1),
#  ('исследований', 1),
#  ('Улицы', 1),
#  ('Чрезвычайные', 1),
#  ('ситуации', 1),
#  ('Штрафы', 1),
#  ('Экономика', 1),
#  ('Австралия', 1),
#  ('Аляска', 1),
#  ('Англия', 1),
#  ('Аргентина', 1),
#  ('Атланта', 1),
#  ('Барселона', 1),
#  ('Берлин', 1),
#  ('Бразилия', 1),
#  ('Брюссель', 1),
#  ('Великий', 1),
#  ('Гамбург', 1),
#  ('Германия', 1),
#  ('Голландия', 1),
#  ('Грузия', 1),
#  ('Дания', 1),
#  ('Европа', 1),
#  ('Екатеринбург', 1),
#  ('Иваново', 1),
#  ('Индия', 1),
#  ('Иркутск', 1),
#  ('Испания', 1),
#  ('Казань', 1),
#  ('Казахстан', 1),
#  ('Калининград', 1),
#  ('Канада', 1),
#  ('Китай', 1),
#  ('Колумбия', 1),
#  ('Коми', 1),
#  ('Копенгаген', 1),
#  ('Краснодар', 1),
#  ('Лейпциг', 1),
#  ('Лос', 1),
#  ('Анджелес', 1),
#  ('Мадрид', 1),
#  ('Мехико', 1),
#  ('Миннеаполис', 1),
#  ('Мир', 1),
#  ('Нижний', 1),
#  ('Новая', 1),
#  ('Зеландия', 1),
#  ('Новочеркасск', 1),
#  ('Норвегия', 1),
#  ('Нью', 1),
#  ('Йорк', 1),
#  ('Омск', 1),
#  ('Осло', 1),
#  ('Париж', 1),
#  ('Пермь', 1),
#  ('Россия', 1),
#  ('Руэда', 1),
#  ('Сеул', 1),
#  ('СНГ', 1),
#  ('США', 1),
#  ('Таллинн', 1),
#  ('Тольятти', 1),
#  ('Тула', 1),
#  ('Финляндия', 1),
#  ('Франция', 1),
#  ('Швейцария', 1),
#  ('Швеция', 1),
#  ('Эстония', 1),
#  ('Автомобили', 1),
#  ('БРТ', 1),
#  ('Велосипед', 1),
#  ('Грузовики', 1),
#  ('Метро', 1),
#  ('Общественный', 1),
#  ('Пешеходы', 1),
#  ('Трамвай', 1),
#  ('Электромобиль', 1),
#  ('Исследования', 1),
#  ('Лекторий', 1),
#  ('Нормативы', 1),
#  ('Отчеты', 1),
#  ('Албин', 1),
#  ('Асаул', 1),
#  ('Асланян', 1),
#  ('Астахов', 1),
#  ('Блинкин', 1),
#  ('Бочаров', 1),
#  ('Буслов', 1),
#  ('Валдин', 1),
#  ('Варламов', 1),
#  ('Власов', 1),
#  ('Гейл', 1),
#  ('Гудвин', 1),
#  ('Джекобс', 1),
#  ('Ефимов', 1),
#  ('Жанказиев', 1),
#  ('Канаев', 1),
#  ('Кац', 1),
#  ('Кирьянов', 1),
#  ('Кузьмин', 1),
#  ('Ликсутов', 1),
#  ('Липович', 1),
#  ('Литвин', 1),
#  ('Лысаков', 1),
#  ('Медведев', 1),
#  ('Минаков', 1),
#  ('Мурашов', 1),
#  ('Нефедов', 1),
#  ('Нилов', 1),
#  ('Петрович', 1),
#  ('Погребняк', 1),
#  ('Полтавченко', 1),
#  ('Поляков', 1),
#  ('Путин', 1),
#  ('Собянин', 1),
#  ('Солодкий', 1),
#  ('Тюльпанов', 1),
#  ('доров', 1),
#  ('Холодов', 1),
#  ('Чаплыгин', 1),
#  ('Шкуматов', 1),
#  ('Шоуп', 1),
#  ('Шувалов', 1),
#  ('Шумский', 1),
#  ('Юрьев', 1),
#  ('Якимов', 1),
#  ('Автостат', 1),
#  ('АТИ', 1),
#  ('ВОЗ', 1),
#  ('ГИБДД', 1),
#  ('Городские', 1),
#  ('проекты', 1),
#  ('МАДИ', 1),
#  ('МВД', 1),
#  ('Минздрав', 1),
#  ('Минтранс', 1),
#  ('НИЦ', 1),
#  ('Пробок', 1),
#  ('РосДорНИИ', 1),
#  ('Строй', 1),
#  ('Инвест', 1),
#  ('Проект', 1),
#  ('ЦОДД', 1),
#  ('Яндекс', 1),
#  ('ГИС', 1),
#  ('мной', 1),
#  ('Письмо', 1),
#  ('ВКонтакте', 1),
#  ('варианты', 1),
#  ('Оставляя', 1),
#  ('персональные', 1),
#  ('данные', 1),
#  ('соглашаетесь', 1),
#  ('Ваших', 1),
#  ('соглашения', 1),
#  ('Выберите', 1),
#  ('список', 1),
#  ('статей', 1),
#  ('новостей', 1),
#  ('Подписаться', 1),
#  ('статьи', 1),
#  ('тему', 1),
#  ('приоритете', 1),
#  ('просветительская', 1),
#  ('деятельность', 1),
#  ('Опыт', 1),
#  ('зарубежных', 1),
#  ('стран', 1),
#  ('Анализ', 1),
#  ('нововведений', 1),
#  ('опечатке', 1),
#  ('который', 1),
#  ('отправлен', 1),
#  ('нашим', 1),
#  ('редакторам', 1),
#  ('Отмена', 1)]
